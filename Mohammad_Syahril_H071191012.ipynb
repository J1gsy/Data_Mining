# %% [markdown]
# <a href="https://colab.research.google.com/github/J1gsy/Data_Mining/blob/main/Mohammad_Syahril_H071191012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tugas Pertemuan 2 Data Mining**
#
# **Nama: Mohammad Syahril**
#
# **NIM: H071191012**
#
# **Kelas: B**

# %% [markdown]
# 1. Cari dan unduh dataset dari repository Kaggle dan UCI machine learning. (harus berbeda setiap individu mahasiswa)
# 2. Ceritakan dataset yang anda ambil dan kira-kira value apa yang anda bisa ambil dari data tersebut(jelaskan jenis atribut).
# 3. Visualisasikan dataset yang anda ambil secara sederhana.
# 4. Deskripsikan informasi statistik dari data anda secara sederhana
#
# note : kerjakan tugas anda dalam bentuk notebook “[nama-nim].ipynb”, dengan bahasa python

# %% [markdown]
# Disini saya sudah mencari dan mengunduh sebuah dataset dari Kaggle, dataset tersebut berjudul "MOVIES DATASET FOR FEATURE EXTRACTION, PREDICTION". Dataset ini diupload oleh seorang contributor bernama Bharat Natrayn. Singkatnya, ia membuat dataset ini untuk membuat rekomendasi film berdasarkan genrenya, serta memprediksi genre suatu film.

# %% [markdown]
# **Deskripsi dataset**
#
# Dataset ini berisi 6817 judul film yang diambil dari imdb top Netflix Movies and TV Shows.
#
# Dalam dataset ini terdapat satu file csv yaitu movies.csv.
# Pada file movies.csv ini berisi judul film dan informasi terkait film tersebut.
#
#
# Beberapa value yang bisa didapat dari dataset ini:
# 1. Daftar film dalam suatu genre tertentu
# 2. Daftar film dengan rating terbaik
# 3. Genre film yang paling populer
# 4. Daftar film dengan rating terburuk
# 5. Dan masih banyak lagi value yang dapat didapat dari informasi film yang tersedia

# %% [markdown]
# **Deskripsi Atribut**
#
#     1. movies.csv
#
# Pada file movies.csv terdapat 9 kolom/atribut. Berikut penjelasannya
#
#
#
# *   movies : berisi judul film
# *   year : berisi tahun film ditayangkan
# *   genre: genre dari film tersebut
# *   rating: penilaian dari penonton tentang film
# *   one_line : deskripsi singkat tentang film
# *   stars : para aktor yang berperan di film
# *   votes : pendapat penonton tentang film
# *   run_time : durasi film

# %% [markdown]
# **Visualisasi dan deskripsi statistik sederhana**

# %%
import pandas as pd

# %% [markdown]
# Mengimport file dengan "read_csv"
#
# dalam contoh ini saya mengimport file dari google drive

# %%
data_movies = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/movies.csv')

# %% [markdown]
# **Melihat data yang sudah diimport dengan menuliskan variabel yang sudah diassign sebelumnya**

# %%
data_movies
# Out:
#                                    MOVIES         YEAR  ... RunTime  Gross
# 0                           Blood Red Sky       (2021)  ...   121.0    NaN
# 1     Masters of the Universe: Revelation     (2021– )  ...    25.0    NaN
# 2                        The Walking Dead  (2010–2022)  ...    44.0    NaN
# 3                          Rick and Morty     (2013– )  ...    23.0    NaN
# 4                         Army of Thieves       (2021)  ...     NaN    NaN
# ...                                   ...          ...  ...     ...    ...
# 9994                       The Imperfects     (2021– )  ...     NaN    NaN
# 9995                               Arcane     (2021– )  ...     NaN    NaN
# 9996                    Heart of Invictus     (2022– )  ...     NaN    NaN
# 9997                       The Imperfects     (2021– )  ...     NaN    NaN
# 9998                       The Imperfects     (2021– )  ...     NaN    NaN
#
# [9999 rows x 9 columns]

# %% [markdown]
# **Melihat 5 indeks awal dan akhir sebuah dataset dengan "head" dan "tail"**

# %%
data_movies.head()
# Out:
#                                 MOVIES         YEAR  ... RunTime  Gross
# 0                        Blood Red Sky       (2021)  ...   121.0    NaN
# 1  Masters of the Universe: Revelation     (2021– )  ...    25.0    NaN
# 2                     The Walking Dead  (2010–2022)  ...    44.0    NaN
# 3                       Rick and Morty     (2013– )  ...    23.0    NaN
# 4                      Army of Thieves       (2021)  ...     NaN    NaN
#
# [5 rows x 9 columns]

# %%
data_movies.tail()
# Out:
#                   MOVIES      YEAR  ... RunTime  Gross
# 9994      The Imperfects  (2021– )  ...     NaN    NaN
# 9995              Arcane  (2021– )  ...     NaN    NaN
# 9996   Heart of Invictus  (2022– )  ...     NaN    NaN
# 9997      The Imperfects  (2021– )  ...     NaN    NaN
# 9998      The Imperfects  (2021– )  ...     NaN    NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# **Info lengkap dari setiap atribut dengan "info"**

# %%
data_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %% [markdown]
# **Mengakses baris dengan "loc"**

# %%
data_movies.loc[:,"RunTime"]
# Out:
# 0       121.0
# 1        25.0
# 2        44.0
# 3        23.0
# 4         NaN
#         ...
# 9994      NaN
# 9995      NaN
# 9996      NaN
# 9997      NaN
# 9998      NaN
# Name: RunTime, Length: 9999, dtype: float64

# %%
data_movies.loc[data_movies.MOVIES =="Rick and Morty"]
# Out:
#            MOVIES      YEAR  ... RunTime  Gross
# 3  Rick and Morty  (2013– )  ...    23.0    NaN
#
# [1 rows x 9 columns]

# %%
data_movies.loc[data_movies.RATING == 5.0]
# Out:
#                                    MOVIES           YEAR  ... RunTime  Gross
# 1     Masters of the Universe: Revelation       (2021– )  ...    25.0    NaN
# 25                              Chernobyl         (2021)  ...   136.0    NaN
# 157                            Bartkowiak         (2021)  ...    91.0    NaN
# 454                          Another Life       (2019– )  ...    43.0    NaN
# 552                           Love Island  (II) (2019– )  ...     NaN    NaN
# ...                                   ...            ...  ...     ...    ...
# 8529                    Too Hot to Handle       (2020– )  ...    42.0    NaN
# 8619                          Chichipatos       (2020– )  ...     NaN    NaN
# 8623                          Chichipatos       (2020– )  ...     NaN    NaN
# 8624                          Chichipatos       (2020– )  ...     NaN    NaN
# 8625                          Chichipatos       (2020– )  ...     NaN    NaN
#
# [67 rows x 9 columns]

# %% [markdown]
# **Mengakses baris dengan "iloc"**

# %%
data_movies.iloc[10]
# Out:
# MOVIES                                    Gunpowder Milkshake
# YEAR                                                   (2021)
# GENRE               \nAction, Adventure, Thriller
# RATING                                                      6
# ONE-LINE    \nThree generations of women fight back agains...
# STARS       \n    Director:\nNavot Papushado\n| \n    Star...
# VOTES                                                  17,989
# RunTime                                                   114
# Gross                                                     NaN
# Name: 10, dtype: object

# %%
data_movies.iloc[[1,99]]
# Out:
#                                  MOVIES         YEAR  ... RunTime  Gross
# 1   Masters of the Universe: Revelation     (2021– )  ...    25.0    NaN
# 99                          Gossip Girl  (2007–2012)  ...    42.0    NaN
#
# [2 rows x 9 columns]

# %%
data_movies.iloc[7:9]
# Out:
#               MOVIES         YEAR  ... RunTime  Gross
# 7             Dexter  (2006–2013)  ...    53.0    NaN
# 8  Never Have I Ever     (2020– )  ...    30.0    NaN
#
# [2 rows x 9 columns]

# %% [markdown]
# **Melihat bentuk data (baris, kolom) dengan "shape"**

# %%
data_movies.shape
# Out:
# (9999, 9)

# %% [markdown]
# **Deskripsi data dengan variabel tertentu seperti count, mean, dll. dengan "describe"**

# %%
data_movies.describe()
# Out:
#             RATING      RunTime
# count  8179.000000  7041.000000
# mean      6.921176    68.688539
# std       1.220232    47.258056
# min       1.100000     1.000000
# 25%       6.200000    36.000000
# 50%       7.100000    60.000000
# 75%       7.800000    95.000000
# max       9.900000   853.000000

# %%
data_movies.describe(include="all")
# Out:
#                   MOVIES      YEAR  ...      RunTime   Gross
# count               9999      9355  ...  7041.000000     460
# unique              6817       438  ...          NaN     332
# top      Bleach: Burîchi  (2020– )  ...          NaN  $0.01M
# freq                  65       892  ...          NaN      22
# mean                 NaN       NaN  ...    68.688539     NaN
# std                  NaN       NaN  ...    47.258056     NaN
# min                  NaN       NaN  ...     1.000000     NaN
# 25%                  NaN       NaN  ...    36.000000     NaN
# 50%                  NaN       NaN  ...    60.000000     NaN
# 75%                  NaN       NaN  ...    95.000000     NaN
# max                  NaN       NaN  ...   853.000000     NaN
#
# [11 rows x 9 columns]

# %%
data_movies.describe(include="object")
# Out:
#                   MOVIES      YEAR                 GENRE  ... STARS VOTES   Gross
# count               9999      9355                  9919  ...  9999  8179     460
# unique              6817       438                   510  ...  7877  4129     332
# top      Bleach: Burîchi  (2020– )  \nComedy              ...    \n     7  $0.01M
# freq                  65       892                   852  ...   456    35      22
#
# [4 rows x 7 columns]

# %% [markdown]
# **Melihat data dengan histogram dengan "hist"**

# %%
data_movies.RATING.hist()

# %% [markdown]
# **Mengubah nama kolom dengan "rename"**
#
# **dalam contoh ini kita mengubah kolom 'YEAR' menjadi 'TAHUN'**

# %%
data_movies.rename(columns={'YEAR':'TAHUN'})
# Out:
#                                    MOVIES        TAHUN  ... RunTime  Gross
# 0                           Blood Red Sky       (2021)  ...   121.0    NaN
# 1     Masters of the Universe: Revelation     (2021– )  ...    25.0    NaN
# 2                        The Walking Dead  (2010–2022)  ...    44.0    NaN
# 3                          Rick and Morty     (2013– )  ...    23.0    NaN
# 4                         Army of Thieves       (2021)  ...     NaN    NaN
# ...                                   ...          ...  ...     ...    ...
# 9994                       The Imperfects     (2021– )  ...     NaN    NaN
# 9995                               Arcane     (2021– )  ...     NaN    NaN
# 9996                    Heart of Invictus     (2022– )  ...     NaN    NaN
# 9997                       The Imperfects     (2021– )  ...     NaN    NaN
# 9998                       The Imperfects     (2021– )  ...     NaN    NaN
#
# [9999 rows x 9 columns]

# %% [markdown]
# **Menghapus kolom dengan "drop"**
#
# **dalam hal ini kita menghapus kolom 'RunTime**'

# %%
data_movies.drop('RunTime',1)
# Out:
#                                    MOVIES         YEAR  ...    VOTES  Gross
# 0                           Blood Red Sky       (2021)  ...   21,062    NaN
# 1     Masters of the Universe: Revelation     (2021– )  ...   17,870    NaN
# 2                        The Walking Dead  (2010–2022)  ...  885,805    NaN
# 3                          Rick and Morty     (2013– )  ...  414,849    NaN
# 4                         Army of Thieves       (2021)  ...      NaN    NaN
# ...                                   ...          ...  ...      ...    ...
# 9994                       The Imperfects     (2021– )  ...      NaN    NaN
# 9995                               Arcane     (2021– )  ...      NaN    NaN
# 9996                    Heart of Invictus     (2022– )  ...      NaN    NaN
# 9997                       The Imperfects     (2021– )  ...      NaN    NaN
# 9998                       The Imperfects     (2021– )  ...      NaN    NaN
#
# [9999 rows x 8 columns]
