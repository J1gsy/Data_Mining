# %% [markdown]
# <a href="https://colab.research.google.com/github/J1gsy/Data_Mining/blob/main/DataMining_Tugas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Mohammad Syahril
#
# ---
#
#
# NIM: H071191023

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Collect data from Kaggle with API

# %% [markdown]
# Set Up to use Kaggle API

# %%
# Install Library Kaggle
# !pip install -q kaggle

# %%
 # Buat direktori  bernama "kaggle"
# !mkdir -p ~/.kaggle

# %%
# Copy the “kaggle.json” ke direktori baru
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# Alokasikan izin yang diperlukan untuk file ini
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !ls -a  #konfigrasi file json
# Out:
# .  ..  .config	drive  sample_data

# %%
# !ls ~/.kaggle/ # perintah untuk melihat daftar sebuah direktori atau direktori aktif di file json

# %% [markdown]
# IMPORT LIBRARY

# %%
#import semua library yang kita butuhkan

import cv2
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import tensorflow as tf
from keras.preprocessing.image import img_to_array
from google.colab import drive

from rpy2.robjects import pandas2ri
from rpy2.robjects import r
from pathlib import Path

pandas2ri.activate()

# %% [markdown]
# Download and Unzip datasets

# %%
# !kaggle datasets download -d residentmario/ramen-ratings # download data set dari kagle
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %% [markdown]
# Baca file data

# %%
# !unzip -q ramen-ratings.zip -d . #mengekstrak file zip yang kita ambil
# Out:
# unzip:  cannot find or open ramen-ratings.zip, ramen-ratings.zip.zip or ramen-ratings.zip.ZIP.

# %%
data = pd.read_csv("ramen-ratings.csv") # membaca data file csv

# %%
data.info() # menampilkan info data  secara signifikan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   object
#  6   Top Ten   41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
data.head() #menammpilkan data value
# Out:
#    Review #           Brand  ... Stars Top Ten
# 0      2580       New Touch  ...  3.75     NaN
# 1      2579        Just Way  ...     1     NaN
# 2      2578          Nissin  ...  2.25     NaN
# 3      2577         Wei Lih  ...  2.75     NaN
# 4      2576  Ching's Secret  ...  3.75     NaN
#
# [5 rows x 7 columns]

# %% [markdown]
# Collect data from device

# %%
from google.colab import files #menerima  file dari google colab kita 
uploaded = files.upload() #upload file
# Out:
#      <input type="file" id="files-6aee28d1-e75f-4899-ab9a-051a00fb7f97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6aee28d1-e75f-4899-ab9a-051a00fb7f97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv

# %%
import io # impirt library io
data1 = pd.read_csv(io.BytesIO(uploaded['StudentsPerformance.csv'])) #membaca data csv
data1.head() #menampilkan data pertama
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %% [markdown]
# Colect data from URL

# %%
data2 = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv") # membaca data csv melalui link url
data2.head() #menampilkan data
# Out:
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                 NaN                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                     NaN

# %% [markdown]
# Colect data from JSON

# %%
import json # import library json

# %%
f = open('iris.json') #  buka file json
data3 = json.load(f) #memuat file json

# %% [markdown]
# Colect data from unidentified package

# %%
! pip install -q pyreadstat #install -q pyreadstat

# %%
#library ReadStat  sangat cepat. Readstat adalah perpustakaan yang digunakan di belakang R library Haven, yang banyak digunakan dan sangat kuat. 
#sehingga  tidak memerlukan menggunakan R (tidak perlu menginstal aplikasi tambahan) dan itu tidak tergantung pada IBM dlls atau perpustakaan eksternal lainnya.
import pyreadstat


#Misalnya, untuk membaca file SPSS sav Anda akan lakukan:
df_employe2 = pd.read_spss('Employee data.sav') # pandas convert the data to object
df_employe2.head() #menampilkan data karyawan2
# Out:
#     id  gender educ    jobcat   salary salbegin jobtime prevexp minority
# 0  1.0    Male   15   Manager  57000.0  27000.0    98.0     144       No
# 1  2.0    Male   16  Clerical  40200.0  18750.0    98.0      36       No
# 2  3.0  Female   12  Clerical  21450.0  12000.0    98.0     381       No
# 3  4.0  Female    8  Clerical  21900.0  13200.0    98.0     190       No
# 4  5.0    Male   15  Clerical  45000.0  21000.0    98.0     138       No

# %% [markdown]
# This is called label encoding

# %%
path = os.listdir("/content/drive/MyDrive/image") 
#metode mengembalikan folder tertentu berisi nama folder. Daftar ini dalam urutan abjad. Ini tidak termasuk '' dan '..' bahkan jika itu di folder

# %%
import PIL # import library pil

# These two variables are "the parameter" of this cell
w = 3
h = 3

# This function uses the open, resize and array function we have seen before 
load_img = lambda filename: np.array(PIL.Image.open(f"/content/drive/MyDrive/image/{filename}").resize((200, 200)))
_, axes_list = plt.subplots(h, w, figsize=(3*w, 3*h)) # define a grid of (w, h)


for axes in axes_list:
  for ax in axes:
    ax.axis('off')
    img = np.random.choice(path) # take a random train filename (like asdfjoi.jpg)
    ax.imshow(load_img(img)) # load and show
    ax.set_title(img)
